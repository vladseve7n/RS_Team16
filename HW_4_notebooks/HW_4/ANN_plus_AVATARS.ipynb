# %%
# !pip install rectools
# !pip install pandas
# !pip install numba
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rectools
#   Downloading RecTools-0.3.0-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 828 kB/s
# Collecting attrs<22.0.0,>=19.1.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 3.7 MB/s
# Collecting Markdown<3.3,>=3.2
#   Downloading Markdown-3.2.2-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 2.5 MB/s
# Requirement already satisfied: numpy<2.0.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from rectools) (1.21.6)
# Requirement already satisfied: scipy<2.0.0,>=1.5.4 in /usr/local/lib/python3.8/dist-packages (from rectools) (1.7.3)
# Collecting implicit==0.4.4
#   Downloading implicit-0.4.4.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 44.6 MB/s
# Requirement already satisfied: pandas<2.0.0,>=0.25.3 in /usr/local/lib/python3.8/dist-packages (from rectools) (1.3.5)
# Requirement already satisfied: typeguard<3.0.0,>=2.0.1 in /usr/local/lib/python3.8/dist-packages (from rectools) (2.7.1)
# Collecting lightfm<2.0,>=1.16
#   Downloading lightfm-1.16.tar.gz (310 kB)
#      |████████████████████████████████| 310 kB 59.3 MB/s
# Collecting nmslib<3.0.0,>=2.0.4
#   Downloading nmslib-2.1.1-cp38-cp38-manylinux2010_x86_64.whl (13.4 MB)
#      |████████████████████████████████| 13.4 MB 59.8 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.27.0 in /usr/local/lib/python3.8/dist-packages (from rectools) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from lightfm<2.0,>=1.16->rectools) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from lightfm<2.0,>=1.16->rectools) (1.0.2)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 80.0 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from nmslib<3.0.0,>=2.0.4->rectools) (5.4.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=0.25.3->rectools) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=0.25.3->rectools) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=0.25.3->rectools) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm<2.0,>=1.16->rectools) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm<2.0,>=1.16->rectools) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm<2.0,>=1.16->rectools) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm<2.0,>=1.16->rectools) (2022.9.24)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lightfm<2.0,>=1.16->rectools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lightfm<2.0,>=1.16->rectools) (3.1.0)
# Building wheels for collected packages: implicit, lightfm
#   Building wheel for implicit (setup.py) ... done
#   Created wheel for implicit: filename=implicit-0.4.4-cp38-cp38-linux_x86_64.whl size=3825479 sha256=f80023a136223d0fde97cda22a120035a8cb6cd75f9f9f9f003142c9bbea4f01
#   Stored in directory: /root/.cache/pip/wheels/00/ac/67/6f4536c819ed560c2c7e17c0f7a920e3e50c26108616087d05
#   Building wheel for lightfm (setup.py) ... done
#   Created wheel for lightfm: filename=lightfm-1.16-cp38-cp38-linux_x86_64.whl size=747383 sha256=ef42e7df1ed6e4b35bce1e06c2eec98c13ce57306124bb817c5d94e88be7c471
#   Stored in directory: /root/.cache/pip/wheels/ec/bb/51/9c487d021c1373b691d13cadca0b65b6852627b1f3f43550fa
# Successfully built implicit lightfm
# Installing collected packages: pybind11, nmslib, Markdown, lightfm, implicit, attrs, rectools
#   Attempting uninstall: Markdown
#     Found existing installation: Markdown 3.4.1
#     Uninstalling Markdown-3.4.1:
#       Successfully uninstalled Markdown-3.4.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# Successfully installed Markdown-3.2.2 attrs-21.4.0 implicit-0.4.4 lightfm-1.16 nmslib-2.1.1 pybind11-2.6.1 rectools-0.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba) (0.39.1)
# Requirement already satisfied: numpy<1.24,>=1.18 in /usr/local/lib/python3.8/dist-packages (from numba) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba) (3.11.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (1.21.6)

# %%
import pandas as pd
import numpy as np
import os

from implicit.als import AlternatingLeastSquares

from rectools.metrics import Precision, Recall, MAP, calc_metrics
from rectools.models import PopularModel, RandomModel, ImplicitALSWrapperModel
from rectools import Columns
from rectools.dataset import Dataset
from rectools.models import ImplicitALSWrapperModel, LightFMWrapperModel

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
from pathlib import Path
import typing as tp
from tqdm import tqdm

from lightfm import LightFM

from implicit.bpr import BayesianPersonalizedRanking

from implicit.lmf import LogisticMatrixFactorization

# %% [markdown]
# ## KION DATA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
url = 'https://github.com/irsafilo/KION_DATASET/raw/f69775be31fa5779907cf0a92ddedb70037fb5ae/data_original.zip'

# %%
req = requests.get(url, stream=True)

with open('kion.zip', 'wb') as fd:
    total_size_in_bytes = int(req.headers.get('Content-Length', 0))
    progress_bar = tqdm(desc='kion dataset download', total=total_size_in_bytes, unit='iB', unit_scale=True)
    for chunk in req.iter_content(chunk_size=2 ** 20):
        progress_bar.update(len(chunk))
        fd.write(chunk)
# Out:
# kion dataset download:  57%|█████▋    | 45.1M/78.8M [00:00<00:00, 446MiB/s]

# %%
import zipfile as zf

files = zf.ZipFile('kion.zip','r')
files.extractall()
files.close()

# %%
interactions = pd.read_csv('data_original/interactions.csv')
Columns.Datetime = 'last_watch_dt'

# %%
users = pd.read_csv('data_original/users.csv')
items = pd.read_csv('data_original/items.csv')

# %% [markdown]
# ### **Interactions prepare**

# %%
interactions.drop(interactions[interactions[Columns.Datetime].str.len() != 10].index, inplace=True)
interactions[Columns.Datetime] = pd.to_datetime(interactions[Columns.Datetime], format='%Y-%m-%d')

# %%
min_date = interactions[Columns.Datetime].min(), 
max_date = interactions[Columns.Datetime].max()

# %%
interactions.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct
# 0   176549     9506    2021-05-11       4250         72.0
# 1   699317     1659    2021-05-29       8317        100.0
# 2   656683     7107    2021-05-09         10          0.0
# 3   864613     7638    2021-07-05      14483        100.0
# 4   964868     9506    2021-04-30       6725        100.0

# %%
interactions[Columns.Weight] = np.where(interactions['watched_pct'] > 10, 3, 1)

# %%
interactions.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct  weight
# 0   176549     9506    2021-05-11       4250         72.0       3
# 1   699317     1659    2021-05-29       8317        100.0       3
# 2   656683     7107    2021-05-09         10          0.0       1
# 3   864613     7638    2021-07-05      14483        100.0       3
# 4   964868     9506    2021-04-30       6725        100.0       3

# %%
train = interactions[interactions[Columns.Datetime] < max_date - pd.Timedelta(days=7)].copy()
test = interactions[interactions[Columns.Datetime] >= max_date - pd.Timedelta(days=7)].copy()

print(f"train: {train.shape}")
print(f"test: {test.shape}")

train.drop(train.query("total_dur < 300").index, inplace=True)

# отфильтруем холодных пользователей из теста
cold_users = set(test[Columns.User]) - set(train[Columns.User])

test.drop(test[test[Columns.User].isin(cold_users)].index, inplace=True)
# Out:
# train: (4985269, 6)
# test: (490982, 6)

# %% [markdown]
# ## User prepare

# %%
users.fillna('Unknown', inplace=True)
users = users.loc[users[Columns.User].isin(train[Columns.User])].copy()

# %%
user_features_frames = []
for feature in ["sex", "age", "income"]:
    feature_frame = users.reindex(columns=[Columns.User, feature])
    feature_frame.columns = ["id", "value"]
    feature_frame["feature"] = feature
    user_features_frames.append(feature_frame)
user_features = pd.concat(user_features_frames)
user_features.head()
# Out:
#         id value feature
# 0   973171     М     sex
# 1   962099     М     sex
# 3   721985     Ж     sex
# 4   704055     Ж     sex
# 5  1037719     М     sex

# %%
train_user_features = user_features.loc[user_features['id'].isin(train[Columns.User])]

# %% [markdown]
# ## Item prepare

# %%
items = items.loc[items[Columns.Item].isin(train[Columns.Item])].copy()

# %% [markdown]
# Genre

# %%
items["genre"] = items["genres"].str.lower().str.replace(", ", ",", regex=False).str.split(",")
genre_feature = items[["item_id", "genre"]].explode("genre")
genre_feature.columns = ["id", "value"]
genre_feature["feature"] = "genre"
genre_feature.head()
# Out:
#       id       value feature
# 0  10711       драмы   genre
# 0  10711  зарубежные   genre
# 0  10711   детективы   genre
# 0  10711   мелодрамы   genre
# 1   2508  зарубежные   genre

# %% [markdown]
# Content

# %%
content_feature = items.reindex(columns=[Columns.Item, "content_type"])
content_feature.columns = ["id", "value"]
content_feature["feature"] = "content_type"
content_feature.head()
# Out:
#       id value       feature
# 0  10711  film  content_type
# 1   2508  film  content_type
# 2  10716  film  content_type
# 3   7868  film  content_type
# 4  16268  film  content_type

# %%
item_features = pd.concat((genre_feature, content_feature))
item_features.head()
# Out:
#       id       value feature
# 0  10711       драмы   genre
# 0  10711  зарубежные   genre
# 0  10711   детективы   genre
# 0  10711   мелодрамы   genre
# 1   2508  зарубежные   genre

# %%
train_item_features = item_features.loc[item_features['id'].isin(train[Columns.Item])]

# %% [markdown]
# ### Save

# %%
interactions.to_csv('prepared_interactions.csv', index=False)
items.to_csv('prepared_items.csv', index=False)
users.to_csv('prepared_users.csv', index=False)
# Out:
# kion dataset download: 100%|██████████| 78.8M/78.8M [00:20<00:00, 446MiB/s]

# %%
item_features.to_csv( 'prepared_featured_items.csv', index=False)
user_features.to_csv('prepared_featured_users.csv', index=False)

# %%
train.to_csv('prepared_interactions_train.csv', index=False)
test.to_csv('prepared_interactions_test.csv', index=False)

train_user_features.to_csv('prepared_featured_users_train.csv', index=False)
train_item_features.to_csv('prepared_featured_items_train.csv', index=False)

# %%
us_dict_map = dict(enumerate(train['user_id'].unique()))
itm_dict_map = dict(enumerate(train['item_id'].unique()))

# %%
dataset = Dataset.construct(
    interactions_df=train,
    user_features_df=user_features,
    cat_user_features=["sex", "age", "income"],
    item_features_df=item_features,
    cat_item_features=["genre", "content_type"],
)

# %% [markdown]
# ## Models

# %%
os.environ["OPENBLAS_NUM_THREADS"] = "1"  # For implicit ALS

import warnings
warnings.filterwarnings('ignore')

# %%
NO_COMP = 64
LEARNING_RATE = 0.1
RANDOM_STATE = 42
NUM_THREADS = 12

# %%
lfm = LightFMWrapperModel(
        model = LightFM(
            no_components=NO_COMP,
            learning_rate=LEARNING_RATE, 
            loss='warp',
            rho=0.9,
            epsilon=1e-5,
            user_alpha=0,
            item_alpha=0,
            random_state=RANDOM_STATE,
        ),
        epochs=1,
        num_threads=NUM_THREADS,
    )
lfm.fit(dataset)

# %% [markdown]
# # ANN

# %%
import nmslib

# %%
import time

# %%
user_embeddings, item_embeddings = lfm.get_vectors(dataset)

# %%
def augment_inner_product(factors):
    normed_factors = np.linalg.norm(factors, axis=1)
    max_norm = normed_factors.max()
    
    extra_dim = np.sqrt(max_norm ** 2 - normed_factors ** 2).reshape(-1, 1)
    augmented_factors = np.append(factors, extra_dim, axis=1)
    return max_norm, augmented_factors

# %%
print('pre shape: ', item_embeddings.shape)
max_norm, augmented_item_embeddings = augment_inner_product(item_embeddings)
augmented_item_embeddings.shape
# Out:
# pre shape:  (14019, 66)
# (14019, 67)

# %%
extra_zero = np.zeros((user_embeddings.shape[0], 1))
augmented_user_embeddings = np.append(user_embeddings, extra_zero, axis=1)
augmented_user_embeddings.shape
# Out:
# (756562, 67)

# %%
# Set index parameters
# These are the most important ones
M = 48
efC = 100

num_threads = 4
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC, 'post' : 0}
print('Index-time parameters', index_time_params)
# Out:
# Index-time parameters {'M': 48, 'indexThreadQty': 4, 'efConstruction': 100, 'post': 0}

# %%
# Number of neighbors 
K=10
# Space name should correspond to the space name 
# used for brute-force search
space_name='negdotprod'

# %%
# Intitialize the library, specify the space, the type of the vector and add data points 
index = nmslib.init(method='hnsw', space=space_name, data_type=nmslib.DataType.DENSE_VECTOR) 
index.addDataPointBatch(augmented_item_embeddings)
# Out:
# 14019

# %%
# Create an index
start = time.time()
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC}
index.createIndex(index_time_params) 
end = time.time() 
print('Index-time parameters', index_time_params)
print('Indexing time = %f' % (end-start))
# Out:
# Index-time parameters {'M': 48, 'indexThreadQty': 4, 'efConstruction': 100}
# Indexing time = 0.914488

# %%
# Setting query-time parameters
efS = 100
query_time_params = {'efSearch': efS}
print('Setting query-time parameters', query_time_params)
index.setQueryTimeParams(query_time_params)
# Out:
# Setting query-time parameters {'efSearch': 100}

# %%
query_matrix = augmented_user_embeddings[:1000, :]

# %%
# Querying
query_qty = query_matrix.shape[0]
start = time.time() 
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)
end = time.time() 
print('kNN time total=%f (sec), per query=%f (sec), per query adjusted for thread number=%f (sec)' % 
      (end-start, float(end-start)/query_qty, num_threads*float(end-start)/query_qty))
# Out:
# kNN time total=0.043361 (sec), per query=0.000043 (sec), per query adjusted for thread number=0.000173 (sec)

# %%
recs = {int(us_dict_map[idx_u]): [int(itm_dict_map[idx_i]) for idx_i in predict[0]] for idx_u, predict in enumerate(nbrs)}

# %%
import json

# %%
with open('ann_recs.json', 'w') as f:
    json.dump(recs, f)

# %% [markdown]
# # AVATARS

# %%
maximums = users.max()

# %%
maximums.user_id
# Out:
# 1097560

# %% [markdown]
# Мама с ребенком (мелодрамы и мультики)

# %%
users = users.append({
    Columns.User: maximums.user_id+1,
    'age': 'age_25_34',
    'income': 'income_20_40',
    'sex': 'Ж',
    'kids_flg': 1
}, ignore_index = True
)

# %%
avatar1_titles = items[items['genres'].str.contains('мультфильмы') | items['genres'].str.contains('мелодрамы')].sample(5, random_state=RANDOM_STATE)['title'].values
avatar1_titles
# Out:
# array(['Аладдин', 'Это моя собака', 'Исцеление (2013)', 'Пять комнат',
#        'Грузовичок Пик'], dtype=object)

# %%
avatar1_interactions = pd.DataFrame({
    "user_id": maximums.user_id+1, 
    "title": avatar1_titles,
    "last_watch_dt": np.full(5, fill_value='2020-06-17'),
    "total_dur": np.full(5, fill_value=np.nan),
    "watched_pct":[100, 100, 70, 70, 70],
    "weight": [5, 3, 3, 5, 1],
    })
avatar1_interactions = avatar1_interactions.merge(items[["item_id", "title", "genres"]], on="title")

# %%
avatar1_interactions
# Out:
#    user_id             title last_watch_dt  total_dur  watched_pct  weight  \
# 0  1097561           Аладдин    2020-06-17        NaN          100       5
# 1  1097561           Аладдин    2020-06-17        NaN          100       5
# 2  1097561    Это моя собака    2020-06-17        NaN          100       3
# 3  1097561  Исцеление (2013)    2020-06-17        NaN           70       3
# 4  1097561       Пять комнат    2020-06-17        NaN           70       5
# 5  1097561    Грузовичок Пик    2020-06-17        NaN           70       1
#
#    item_id                                             genres
# 0    12421  мультфильм, приключения, мюзиклы, мелодрамы, ф...
# 1    11310                    фэнтези, приключения, мелодрамы
# 2     9925                                 русские, мелодрамы
# 3     7040                                 русские, мелодрамы
# 4     3333                                 мелодрамы, комедии
# 5     8453             развлекательные, развитие, мультфильмы

# %% [markdown]
# Пожелой мужчина, исторические фильмы

# %%
users = users.append({
    Columns.User: maximums.user_id+2,
    'age': 'age_65_inf',
    'income': 'income_40_60',
    'sex': 'М',
    'kids_flg': 0
}, ignore_index = True
)

# %%
avatar2_titles = items[items['genres'].str.contains('исторические')].sample(5, random_state=RANDOM_STATE)['title'].values
avatar2_titles
# Out:
# array(['Заговор против Америки', '1812', 'Тачанка с юга',
#        'Пираты семи морей: Черная борода', 'Падение последней империи'],
#       dtype=object)

# %%
avatar2_interactions = pd.DataFrame({
    "user_id": maximums.user_id+2, 
    "title": avatar2_titles,
    "last_watch_dt": np.full(5, fill_value='2020-06-17'),
    "total_dur": np.full(5, fill_value=np.nan),
    "watched_pct":[70, 80, 70, 70, 70],
    "weight": [5, 5, 5, 5, 1],
    })
avatar2_interactions = avatar2_interactions.merge(items[["item_id", "title", "genres"]], on="title")

# %%
avatar2_interactions
# Out:
#    user_id                             title last_watch_dt  total_dur  \
# 0  1097562            Заговор против Америки    2020-06-17        NaN
# 1  1097562                              1812    2020-06-17        NaN
# 2  1097562                     Тачанка с юга    2020-06-17        NaN
# 3  1097562  Пираты семи морей: Черная борода    2020-06-17        NaN
# 4  1097562         Падение последней империи    2020-06-17        NaN
#
#    watched_pct  weight  item_id  \
# 0           70       5    10620
# 1           80       5     3726
# 2           70       5     4243
# 3           70       5     8102
# 4           70       1     9431
#
#                                               genres
# 0                    драмы, исторические, фантастика
# 1  русские, познавательные, драмы, исторические, ...
# 2               исторические, советские, приключения
# 3  приключения, зарубежные, исторические, военные...
# 4  приключения, драмы, зарубежные, исторические, ...

# %% [markdown]
# Неразделенная любовь (зарубежные драмы)

# %%
users = users.append({
    Columns.User: maximums.user_id+3,
    'age': 'age_18_24',
    'income': 'income_0_20',
    'sex': 'Ж',
    'kids_flg': 0
}, ignore_index = True
)

# %%
avatar3_titles = items[items['genres'].str.contains('драмы') & items['genres'].str.contains('зарубежные')].sample(5, random_state=RANDOM_STATE)['title'].values
avatar3_titles
# Out:
# array(['Стриптизерши', 'Мэгги и Бьянка в Академии моды',
#        '[4K] На глубине 6 футов', 'До свидания там, наверху',
#        'Сокровище нации'], dtype=object)

# %%
avatar3_interactions = pd.DataFrame({
    "user_id": maximums.user_id+3, 
    "title": avatar3_titles,
    "last_watch_dt": np.full(5, fill_value='2020-06-17'),
    "total_dur": np.full(5, fill_value=np.nan),
    "watched_pct":[100, 90, 90, 90, 90],
    "weight": [5, 4, 1, 3, 2]})
avatar3_interactions = avatar3_interactions.merge(items[["item_id", "title", "genres"]], on="title")

# %%
avatar3_interactions
# Out:
#    user_id                           title last_watch_dt  total_dur  \
# 0  1097563                    Стриптизерши    2020-06-17        NaN
# 1  1097563  Мэгги и Бьянка в Академии моды    2020-06-17        NaN
# 2  1097563         [4K] На глубине 6 футов    2020-06-17        NaN
# 3  1097563        До свидания там, наверху    2020-06-17        NaN
# 4  1097563                 Сокровище нации    2020-06-17        NaN
# 5  1097563                 Сокровище нации    2020-06-17        NaN
#
#    watched_pct  weight  item_id  \
# 0          100       5    16487
# 1           90       4     9166
# 2           90       1      407
# 3           90       3     3245
# 4           90       2    11458
# 5           90       2    15647
#
#                                               genres
# 0               драмы, зарубежные, криминал, комедии
# 1    драмы, зарубежные, мелодрамы, семейное, комедии
# 2  биография, приключения, драмы, зарубежные, три...
# 3                                  драмы, зарубежные
# 4                     боевики, триллеры, приключения
# 5                                  драмы, зарубежные

# %%
avatar1_interactions[Columns.Datetime] = pd.to_datetime(avatar1_interactions[Columns.Datetime], format='%Y-%m-%d')
avatar2_interactions[Columns.Datetime] = pd.to_datetime(avatar2_interactions[Columns.Datetime], format='%Y-%m-%d')
avatar3_interactions[Columns.Datetime] = pd.to_datetime(avatar3_interactions[Columns.Datetime], format='%Y-%m-%d')

# %%
train
# Out:
#          user_id  item_id last_watch_dt  total_dur  watched_pct  weight
# 0         176549     9506    2021-05-11       4250         72.0       3
# 1         699317     1659    2021-05-29       8317        100.0       3
# 3         864613     7638    2021-07-05      14483        100.0       3
# 4         964868     9506    2021-04-30       6725        100.0       3
# 5        1032142     6686    2021-05-13      11286        100.0       3
# ...          ...      ...           ...        ...          ...     ...
# 5476242   268216     3071    2021-04-21       5752         98.0       3
# 5476244   438585     7829    2021-08-02       6804        100.0       3
# 5476245   786732     4880    2021-05-12        753          0.0       1
# 5476247   546862     9673    2021-04-13       2308         49.0       3
# 5476249   384202    16197    2021-04-19       6203        100.0       3
#
# [3832711 rows x 6 columns]

# %%
train_avatars = pd.concat([
    train, 
    avatar1_interactions.drop(['title', 'genres'], axis=1),
    avatar2_interactions.drop(['title', 'genres'], axis=1), 
    avatar3_interactions.drop(['title', 'genres'], axis=1),
], sort=False)
train_avatars.tail(30)
# Out:
#          user_id  item_id last_watch_dt  total_dur  watched_pct  weight
# 5476231   503488    15997    2021-04-01      397.0          7.0       1
# 5476232   699405     4702    2021-05-20     1709.0         28.0       3
# 5476233   399997    14901    2021-07-31      489.0          8.0       1
# 5476234   814537     1856    2021-05-15      713.0         79.0       3
# 5476235   977542    13126    2021-07-04     1830.0         26.0       3
# 5476239   610017     7107    2021-05-10     1133.0         75.0       3
# 5476240   802291      512    2021-08-08     6990.0        100.0       3
# 5476241  1073802     9927    2021-08-07     6425.0         97.0       3
# 5476242   268216     3071    2021-04-21     5752.0         98.0       3
# 5476244   438585     7829    2021-08-02     6804.0        100.0       3
# 5476245   786732     4880    2021-05-12      753.0          0.0       1
# 5476247   546862     9673    2021-04-13     2308.0         49.0       3
# 5476249   384202    16197    2021-04-19     6203.0        100.0       3
# 0        1097561    12421    2020-06-17        NaN        100.0       5
# 1        1097561    11310    2020-06-17        NaN        100.0       5
# 2        1097561     9925    2020-06-17        NaN        100.0       3
# 3        1097561     7040    2020-06-17        NaN         70.0       3
# 4        1097561     3333    2020-06-17        NaN         70.0       5
# 5        1097561     8453    2020-06-17        NaN         70.0       1
# 0        1097562    10620    2020-06-17        NaN         70.0       5
# 1        1097562     3726    2020-06-17        NaN         80.0       5
# 2        1097562     4243    2020-06-17        NaN         70.0       5
# 3        1097562     8102    2020-06-17        NaN         70.0       5
# 4        1097562     9431    2020-06-17        NaN         70.0       1
# 0        1097563    16487    2020-06-17        NaN        100.0       5
# 1        1097563     9166    2020-06-17        NaN         90.0       4
# 2        1097563      407    2020-06-17        NaN         90.0       1
# 3        1097563     3245    2020-06-17        NaN         90.0       3
# 4        1097563    11458    2020-06-17        NaN         90.0       2
# 5        1097563    15647    2020-06-17        NaN         90.0       2

# %%
dataset_av = Dataset.construct(
    interactions_df=train_avatars,
    user_features_df=user_features,
    cat_user_features=["sex", "age", "income"],
    item_features_df=item_features,
    cat_item_features=["genre", "content_type", "countries"],
)

# %%
NO_COMP = 64
LEARNING_RATE = 0.1
RANDOM_STATE = 42
NUM_THREADS = 12
K_RECOS = 10

# %%
lfm = LightFMWrapperModel(
        model = LightFM(
            no_components=NO_COMP,
            learning_rate=LEARNING_RATE, 
            loss='warp',
            rho=0.9,
            epsilon=1e-5,
            user_alpha=0,
            item_alpha=0,
            random_state=RANDOM_STATE,
        ),
        epochs=1,
        num_threads=NUM_THREADS,
    )
lfm.fit(dataset_av)

# %%
av = pd.concat((avatar1_interactions, avatar2_interactions, avatar3_interactions))

# %%
av_ids = av['user_id'].unique()

# %%
recs_av = lfm.recommend(
    users=av_ids,
    dataset=dataset_av,
    k=K_RECOS,
    filter_viewed=True,
)

# %%
recoms = recs_av.merge( items[['item_id', 'title', 'countries', 'genre']], on='item_id')

# %%
recoms
# Out:
#     user_id  item_id      score  rank  \
# 0   1097561     8131  19.808957     1
# 1   1097561    13191  17.220926     2
# 2   1097561     9234  14.787405     3
# 3   1097561     4398  14.041927     4
# 4   1097561     8083  13.123398     5
# 5   1097561     3606  11.779671     6
# 6   1097561    12988  10.760368     7
# 7   1097561    10323  10.680384     8
# 8   1097561    13069  10.470164     9
# 9   1097561     7571  10.426362    10
# 10  1097562    10794  22.110605     1
# 11  1097562     4389  17.964733     2
# 12  1097562     4748  16.162696     3
# 13  1097562      160  15.566936     4
# 14  1097562     3375  15.461874     5
# 15  1097562    15279  15.410039     6
# 16  1097562     5079  14.869333     7
# 17  1097562     3248  14.812299     8
# 18  1097562     5172  14.802380     9
# 19  1097562     1885  14.715634    10
# 20  1097563    13085  28.213650     1
# 21  1097563    16178  27.874390     2
# 22  1097563    11964  27.011906     3
# 23  1097563     5836  26.818923     4
# 24  1097563    10433  26.106274     5
# 25  1097563    15322  25.533422     6
# 26  1097563    13539  25.526441     7
# 27  1097563     5654  25.489154     8
# 28  1097563    10006  25.460706     9
# 29  1097563     1611  24.931675    10
#
#                                          title  \
# 0   Чтобы увидеть радугу, нужно пережить дождь
# 1                                 Ночь в музее
# 2                               Бои без правил
# 3                                   Муж на час
# 4                             Спящая красавица
# 5                            Грешники и святые
# 6                           Гномео и Джульетта
# 7                         Университет монстров
# 8                                  Книга жизни
# 9                                    100% волк
# 10                      Вы заказывали убийство
# 11                           Приходи свободным
# 12                                  Отключение
# 13                             Крейсер «Варяг»
# 14         Провал операции «Большая Медведица»
# 15                        Горький можжевельник
# 16                            Красавица и воры
# 17                                  Хорнблауэр
# 18                                Чистая проба
# 19                               Личные мотивы
# 20                                        Буу!
# 21                                    Идеалист
# 22                              Изменение духа
# 23                             Хозяин джунглей
# 24                              Цирк мертвецов
# 25         Самая красивая (на казахском языке)
# 26                               В тихом омуте
# 27                          Случайно беременна
# 28                             Не стучи дважды
# 29                       Мой дядя Джон – зомби
#
#                                             countries  \
# 0                                             Украина
# 1                                 США, Великобритания
# 2   Великобритания, Франция, Китай, Камбоджа, США,...
# 3                                             Украина
# 4                                                 США
# 5                                                 США
# 6                         Великобритания, США, Канада
# 7                                                 США
# 8                                                 США
# 9                                  Австралия, Бельгия
# 10                                             Россия
# 11                                               СССР
# 12                                            Бельгия
# 13                                               СССР
# 14                                               СССР
# 15                                               СССР
# 16                                             Россия
# 17                                     Великобритания
# 18                                             Россия
# 19                                             Россия
# 20                                                США
# 21                                         Дания, США
# 22                                                США
# 23                                 Аргентина, Мексика
# 24                                                США
# 25                                          Казахстан
# 26                                            Франция
# 27                                            Франция
# 28                                     Великобритания
# 29                                                США
#
#                                                 genre
# 0                   [зарубежные, криминал, мелодрамы]
# 1           [семейное, фэнтези, приключения, комедии]
# 2       [биография, криминал, драмы, спорт, триллеры]
# 3                                [мелодрамы, комедии]
# 4           [мюзиклы, мультфильм, фэнтези, мелодрамы]
# 5                       [боевики, триллеры, криминал]
# 6       [мелодрамы, мультфильм, приключения, комедии]
# 7         [мультфильм, фэнтези, приключения, комедии]
# 8   [мультфильм, приключения, мюзиклы, мелодрамы, ...
# 9   [мультфильм, приключения, семейное, фэнтези, к...
# 10                               [русские, детективы]
# 11          [драмы, исторические, советские, военные]
# 12           [драмы, зарубежные, триллеры, детективы]
# 13          [драмы, исторические, советские, военные]
# 14                        [драмы, советские, военные]
# 15                          [драмы, русские, военные]
# 16                    [русские, детективы, мелодрамы]
# 17          [драмы, зарубежные, военные, приключения]
# 18                  [детективы, русские, приключения]
# 19                  [медицинские, русские, детективы]
# 20                       [зарубежные, мистика, ужасы]
# 21                             [зарубежные, триллеры]
# 22                  [боевики, зарубежные, фантастика]
# 23                       [драмы, зарубежные, вестерн]
# 24             [боевики, зарубежные, триллеры, ужасы]
# 25                    [зарубежные, криминал, комедии]
# 26                              [зарубежные, комедии]
# 27                              [зарубежные, комедии]
# 28                                [зарубежные, ужасы]
# 29                       [зарубежные, комедии, ужасы]

# %% [markdown]
# **Рекомендации для мамы с ребенком (мультфильмы + мелодрамы)**

# %%
recoms[recoms.user_id == 1097561]
# Out:
#    user_id  item_id      score  rank  \
# 0  1097561     8131  19.808957     1
# 1  1097561    13191  17.220926     2
# 2  1097561     9234  14.787405     3
# 3  1097561     4398  14.041927     4
# 4  1097561     8083  13.123398     5
# 5  1097561     3606  11.779671     6
# 6  1097561    12988  10.760368     7
# 7  1097561    10323  10.680384     8
# 8  1097561    13069  10.470164     9
# 9  1097561     7571  10.426362    10
#
#                                         title  \
# 0  Чтобы увидеть радугу, нужно пережить дождь
# 1                                Ночь в музее
# 2                              Бои без правил
# 3                                  Муж на час
# 4                            Спящая красавица
# 5                           Грешники и святые
# 6                          Гномео и Джульетта
# 7                        Университет монстров
# 8                                 Книга жизни
# 9                                   100% волк
#
#                                            countries  \
# 0                                            Украина
# 1                                США, Великобритания
# 2  Великобритания, Франция, Китай, Камбоджа, США,...
# 3                                            Украина
# 4                                                США
# 5                                                США
# 6                        Великобритания, США, Канада
# 7                                                США
# 8                                                США
# 9                                 Австралия, Бельгия
#
#                                                genre
# 0                  [зарубежные, криминал, мелодрамы]
# 1          [семейное, фэнтези, приключения, комедии]
# 2      [биография, криминал, драмы, спорт, триллеры]
# 3                               [мелодрамы, комедии]
# 4          [мюзиклы, мультфильм, фэнтези, мелодрамы]
# 5                      [боевики, триллеры, криминал]
# 6      [мелодрамы, мультфильм, приключения, комедии]
# 7        [мультфильм, фэнтези, приключения, комедии]
# 8  [мультфильм, приключения, мюзиклы, мелодрамы, ...
# 9  [мультфильм, приключения, семейное, фэнтези, к...

# %% [markdown]
# Как видно, мультфильмы и мелодрамы преобладают, но есть и неподходящие категории

# %% [markdown]
# **Рекомендации для люителя исторических фильмов**

# %%
recoms[recoms.user_id == 1097562]
# Out:
#     user_id  item_id      score  rank                                title  \
# 10  1097562    10794  22.110605     1               Вы заказывали убийство
# 11  1097562     4389  17.964733     2                    Приходи свободным
# 12  1097562     4748  16.162696     3                           Отключение
# 13  1097562      160  15.566936     4                      Крейсер «Варяг»
# 14  1097562     3375  15.461874     5  Провал операции «Большая Медведица»
# 15  1097562    15279  15.410039     6                 Горький можжевельник
# 16  1097562     5079  14.869333     7                     Красавица и воры
# 17  1097562     3248  14.812299     8                           Хорнблауэр
# 18  1097562     5172  14.802380     9                         Чистая проба
# 19  1097562     1885  14.715634    10                        Личные мотивы
#
#          countries                                      genre
# 10          Россия                       [русские, детективы]
# 11            СССР  [драмы, исторические, советские, военные]
# 12         Бельгия   [драмы, зарубежные, триллеры, детективы]
# 13            СССР  [драмы, исторические, советские, военные]
# 14            СССР                [драмы, советские, военные]
# 15            СССР                  [драмы, русские, военные]
# 16          Россия            [русские, детективы, мелодрамы]
# 17  Великобритания  [драмы, зарубежные, военные, приключения]
# 18          Россия          [детективы, русские, приключения]
# 19          Россия          [медицинские, русские, детективы]

# %% [markdown]
# **Рекомендации для пользователя с зарубежными драмами**

# %%
recoms[recoms.user_id == 1097563]
# Out:
#     user_id  item_id      score  rank                                title  \
# 20  1097563    13085  28.213650     1                                 Буу!
# 21  1097563    16178  27.874390     2                             Идеалист
# 22  1097563    11964  27.011906     3                       Изменение духа
# 23  1097563     5836  26.818923     4                      Хозяин джунглей
# 24  1097563    10433  26.106274     5                       Цирк мертвецов
# 25  1097563    15322  25.533422     6  Самая красивая (на казахском языке)
# 26  1097563    13539  25.526441     7                        В тихом омуте
# 27  1097563     5654  25.489154     8                   Случайно беременна
# 28  1097563    10006  25.460706     9                      Не стучи дважды
# 29  1097563     1611  24.931675    10                Мой дядя Джон – зомби
#
#              countries                                   genre
# 20                 США            [зарубежные, мистика, ужасы]
# 21          Дания, США                  [зарубежные, триллеры]
# 22                 США       [боевики, зарубежные, фантастика]
# 23  Аргентина, Мексика            [драмы, зарубежные, вестерн]
# 24                 США  [боевики, зарубежные, триллеры, ужасы]
# 25           Казахстан         [зарубежные, криминал, комедии]
# 26             Франция                   [зарубежные, комедии]
# 27             Франция                   [зарубежные, комедии]
# 28      Великобритания                     [зарубежные, ужасы]
# 29                 США            [зарубежные, комедии, ужасы]
