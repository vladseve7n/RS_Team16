# %%
import pandas as pd
import numpy as np

# 0.3.0
from rectools import Columns
from rectools.dataset import Dataset

# %% [markdown]
# ## Getting preprocess dataset

# %%
interactions = pd.read_csv('data/interactions.csv', index_col=0)
users = pd.read_csv('data/users.csv', index_col=0)
items = pd.read_csv('data/items.csv', index_col=0)

# %%
interactions.head(3)
# Out:
#    user_id  item_id    datetime  weight  watched_pct
# 0   176549     9506  2021-05-11    4250         72.0
# 1   699317     1659  2021-05-29    8317        100.0
# 2   656683     7107  2021-05-09      10          0.0

# %%
users.head(3)
# Out:
#    user_id        age        income sex  kids_flg
# 0   973171  age_25_34  income_60_90   М         1
# 1   962099  age_18_24  income_20_40   М         0
# 2  1047345  age_45_54  income_40_60   Ж         0

# %%
items.head(3)
# Out:
#    item_id content_type             title      title_orig  release_year  \
# 0    10711         film    Поговори с ней  Hable con ella        2002.0
# 1     2508         film       Голые перцы    Search Party        2014.0
# 2    10716         film  Тактическая сила  Tactical Force        2011.0
#
#                                              genres countries  for_kids  \
# 0           драмы, зарубежные, детективы, мелодрамы   Испания       NaN
# 1                  зарубежные, приключения, комедии       США       NaN
# 2  криминал, зарубежные, триллеры, боевики, комедии    Канада       NaN
#
#    age_rating studios         directors  \
# 0        16.0     NaN  Педро Альмодовар
# 1        16.0     NaN    Скот Армстронг
# 2        16.0     NaN  Адам П. Калтраро
#
#                                               actors  \
# 0  Адольфо Фернандес, Ана Фернандес, Дарио Гранди...
# 1  Адам Палли, Брайан Хаски, Дж.Б. Смув, Джейсон ...
# 2  Адриан Холмс, Даррен Шалави, Джерри Вассерман,...
#
#                                          description  \
# 0  Мелодрама легендарного Педро Альмодовара «Пого...
# 1  Уморительная современная комедия на популярную...
# 2  Профессиональный рестлер Стив Остин («Все или ...
#
#                                             keywords
# 0  Поговори, ней, 2002, Испания, друзья, любовь, ...
# 1  Голые, перцы, 2014, США, друзья, свадьбы, прео...
# 2  Тактическая, сила, 2011, Канада, бандиты, ганг...

# %% [markdown]
# ## Preparing data for ```rectools.dataset.Dataset``` class

# %% [markdown]
# ### Item features construction

# %% [markdown]
# Binarize years in release_year feature

# %% [markdown]
# Creating year_feature df

# %%
_, bins = pd.qcut(items["release_year"], 10, retbins=True)
year_feature = pd.DataFrame(
    {
        "id": items["item_id"],
        "value": pd.cut(items["release_year"], bins=bins, labels=bins[:-1]),
        "feature": "release_year",
    }
)
year_feature.head()
# Out:
#       id   value       feature
# 0  10711  1983.0  release_year
# 1   2508  2012.0  release_year
# 2  10716  2009.0  release_year
# 3   7868  2014.0  release_year
# 4  16268  1897.0  release_year

# %% [markdown]
# Adding genres like features

# %%
items["genre"] = items["genres"].str.split(",")
genre_feature = items[["item_id", "genre"]].explode("genre")
genre_feature.columns = ["id", "value"]
genre_feature["feature"] = "genre"
genre_feature.head()
# Out:
#       id        value feature
# 0  10711        драмы   genre
# 0  10711   зарубежные   genre
# 0  10711    детективы   genre
# 0  10711    мелодрамы   genre
# 1   2508   зарубежные   genre

# %% [markdown]
# Adding age_rating like feature

# %%
age_rating_feature = items[['item_id', 'age_rating']].dropna()
age_rating_feature.columns = ["id", "value"]
age_rating_feature['feature'] = 'age_rating'
age_rating_feature.head()
# Out:
#       id  value     feature
# 0  10711   16.0  age_rating
# 1   2508   16.0  age_rating
# 2  10716   16.0  age_rating
# 3   7868   16.0  age_rating
# 4  16268   12.0  age_rating

# %%
content_type_feature = items[['item_id', 'content_type']].dropna()
content_type_feature.columns = ["id", "value"]
content_type_feature['feature'] = 'content_type'
content_type_feature.head()
# Out:
#       id value       feature
# 0  10711  film  content_type
# 1   2508  film  content_type
# 2  10716  film  content_type
# 3   7868  film  content_type
# 4  16268  film  content_type

# %% [markdown]
# Creating general item_feat

# %%
item_feat = pd.concat([genre_feature, 
                       year_feature, 
                       age_rating_feature,
                       content_type_feature])
item_feat = item_feat[item_feat['id'].isin(interactions['item_id'])]

# %%
item_feat
# Out:
#           id        value       feature
# 0      10711        драмы         genre
# 0      10711   зарубежные         genre
# 0      10711    детективы         genre
# 0      10711    мелодрамы         genre
# 1       2508   зарубежные         genre
# ...      ...          ...           ...
# 15958   6443       series  content_type
# 15959   2367       series  content_type
# 15960  10632       series  content_type
# 15961   4538       series  content_type
# 15962   3206       series  content_type
#
# [87086 rows x 3 columns]

# %% [markdown]
# ### User features construction

# %% [markdown]
# Adding age like a feature

# %%
from sklearn import preprocessing
age_feature = users[['user_id', 'age']].dropna()
age_feature.columns = ["id", "value"]
# Let's convert categorical type into int for age
lab_encoder = preprocessing.LabelEncoder()
age_feature['value'] = lab_encoder.fit_transform(age_feature['value'])
age_feature['feature'] = 'age'
age_feature.head()
# Out:
#         id  value feature
# 0   973171      1     age
# 1   962099      0     age
# 2  1047345      3     age
# 3   721985      3     age
# 4   704055      2     age

# %% [markdown]
# Adding sex like a feature

# %%
sex_feature = users[['user_id', 'sex']].dropna()
sex_feature.columns = ["id", "value"]
# Converting categorical feature to int
sex_feature['value'] = lab_encoder.fit_transform(sex_feature['value'])
sex_feature['feature'] = 'age'
sex_feature.head()
# Out:
#         id  value feature
# 0   973171      1     age
# 1   962099      1     age
# 2  1047345      0     age
# 3   721985      0     age
# 4   704055      0     age

# %% [markdown]
# Creating general user_feat

# %%
user_feat = pd.concat([age_feature,
                       sex_feature
                      ])
user_feat = user_feat[user_feat['id'].isin(interactions['user_id'])]

# %% [markdown]
# ### Constracting ```Dataset``` object

# %%
dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=user_feat,
    item_features_df=item_feat,
    cat_item_features=['genre', 
                       'release_year',
                       'age_rating',
                       'content_type'
                      ],
    cat_user_features=['age', 'sex']
)

# %% [markdown]
# ### Creating simple pop model

# %%
from rectools.models.popular import PopularModel

# %% [markdown]
# Creating models with different 'popularity score' methods evaling

# %%
# %%time
pop_n_users = PopularModel()
pop_n_users.fit(dataset);
# Out:
# CPU times: user 1.54 s, sys: 112 ms, total: 1.65 s
# Wall time: 1.65 s

# %%
# %%time
pop_n_interactions = PopularModel(popularity='n_interactions')
pop_n_interactions.fit(dataset)
# Out:
# CPU times: user 65.5 ms, sys: 28.7 ms, total: 94.2 ms
# Wall time: 93.7 ms

# %%
# %%time
pop_mean_weight = PopularModel(popularity='mean_weight')
pop_mean_weight.fit(dataset)
# Out:
# CPU times: user 81.7 ms, sys: 607 µs, total: 82.3 ms
# Wall time: 83.5 ms

# %%
# %%time
pop_sum_weight = PopularModel(popularity='sum_weight')
pop_sum_weight.fit(dataset);
# Out:
# CPU times: user 71.2 ms, sys: 11.6 ms, total: 82.8 ms
# Wall time: 82.4 ms

# %%
pd.concat([
    pop_n_users.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
    
    pop_n_interactions.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
    
    pop_mean_weight.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
    
    pop_sum_weight.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
], axis=1).drop(['user_id', 'rank'], axis=1)
# Out:
#    item_id     score                         title content_type  item_id  \
# 0    10440  202457.0                   Хрустальный       series    10440
# 1    15297  193123.0               Клиника счастья       series    15297
# 2     9728  132865.0             Гнев человеческий         film     9728
# 3    13865  122119.0                      Девятаев         film    13865
# 4     4151   91167.0        Секреты семейной жизни       series     4151
# 5     3734   74803.0  Прабабушка легкого поведения         film     3734
# 6     2657   68581.0                    Подслушано       series     2657
# 7     4880   55043.0                         Афера       series     4880
# 8      142   45367.0                          Маша         film      142
# 9     6809   40372.0                         Дуров         film     6809
#
#       score                         title content_type  item_id  \
# 0  202457.0                   Хрустальный       series     1714
# 1  193123.0               Клиника счастья       series     3642
# 2  132865.0             Гнев человеческий         film      856
# 3  122119.0                      Девятаев         film     3480
# 4   91167.0        Секреты семейной жизни       series    16216
# 5   74803.0  Прабабушка легкого поведения         film    13395
# 6   68581.0                    Подслушано       series    11566
# 7   55043.0                         Афера       series     1914
# 8   45367.0                          Маша         film     2788
# 9   40372.0                         Дуров         film     3750
#
#            score               title content_type  item_id         score  \
# 0  635143.666667     Люби меня таким       series    10440  5.534083e+09
# 1  442423.000000  Обручальное кольцо       series    15297  4.432354e+09
# 2  400153.000000   Приют комедиантов       series     4151  9.591958e+08
# 3  373410.666667         Жизнь Мехэк       series     6192  9.368519e+08
# 4  340005.500000      Анна-детективъ       series       14  8.652617e+08
# 5  339193.000000             Крамола       series    13865  8.187124e+08
# 6  328638.566667       Татьянин день       series     9728  7.817209e+08
# 7  294688.000000       Неравный брак       series     9996  6.297195e+08
# 8  290355.500000               Ганга       series    16228  5.796793e+08
# 9  285721.000000       Юлия Высоцкая       series      496  4.452146e+08
#
#                     title content_type
# 0             Хрустальный       series
# 1         Клиника счастья       series
# 2  Секреты семейной жизни       series
# 3   Отчаянные домохозяйки       series
# 4        Жестокий Стамбул       series
# 5                Девятаев         film
# 6       Гнев человеческий         film
# 7                   Немцы       series
# 8              Содержанки       series
# 9     Воскресший Эртугрул       series

# %% [markdown]
# As we can see:
#  - There is no difference between n_users and n_iteractions (may be it linked with that all users interact with popular items no more than once);
#  - mean_weight and sum_weight method doesn't work good with not normed weights, because there are only series in the top for mean_weight method.
#
#  So let's normalize weights for interaction in order to get better results

# %% [markdown]
# Weight attribute of the dataset shows the time that user spend to interact with item. So it is obvious that users spend more time for series than for films and others

# %%
interactions.merge(
    items[['content_type', 'item_id']], 
    on='item_id', 
    how='left'
).groupby('content_type')['weight'].mean()
# Out:
# content_type
# film       4570.452922
# series    19803.803874
# Name: weight, dtype: float64

# %% [markdown]
# But there is another attribute that can be helpful for us. This attribute is ```watched_pct``` that we can use like a weight, because it shows us how many percent of item have been watched by user

# %% [markdown]
# ### Let's create mean_weights, sum_weights models using watched_pct, like a weight

# %%
interactions_pct = interactions.copy()
interactions_pct[Columns.Weight] = interactions_pct['watched_pct']
interactions_pct.drop('watched_pct', axis=1, inplace=True)
interactions_pct.head(2)
# Out:
#    user_id  item_id    datetime  weight
# 0   176549     9506  2021-05-11    72.0
# 1   699317     1659  2021-05-29   100.0

# %%
dataset_pct = Dataset.construct(
    interactions_df=interactions_pct,
    user_features_df=user_feat,
    item_features_df=item_feat,
    cat_item_features=['genre', 
                       'release_year',
                       'age_rating',
                       'content_type'
                      ],
    cat_user_features=['age', 'sex']
)

# %%
# %%time
pop_mean_weight_pct = PopularModel(popularity='mean_weight')
pop_mean_weight_pct.fit(dataset_pct);
# Out:
# CPU times: user 87.2 ms, sys: 1.31 ms, total: 88.5 ms
# Wall time: 100 ms

# %%
# %%time
pop_sum_weight_pct = PopularModel(popularity='sum_weight')
pop_sum_weight_pct.fit(dataset_pct);
# Out:
# CPU times: user 69.9 ms, sys: 8.78 ms, total: 78.7 ms
# Wall time: 77.9 ms

# %%
pd.concat([
    pd.concat([
        pop_mean_weight.recommend(
            dataset.user_id_map.external_ids[:1], 
            dataset=dataset, 
            k=10, 
            filter_viewed=False  # False - same items to every user
        ).merge(items[['item_id', 'title', 'content_type']], 
               on='item_id',
               how='left'),

        pop_sum_weight.recommend(
            dataset.user_id_map.external_ids[:1], 
            dataset=dataset, 
            k=10, 
            filter_viewed=False  # False - same items to every user
        ).merge(items[['item_id', 'title', 'content_type']], 
               on='item_id',
               how='left'),
    ], axis=1).drop(['user_id', 'rank'], axis=1),

    pd.concat([
        pop_mean_weight_pct.recommend(
            dataset_pct.user_id_map.external_ids[:1], 
            dataset=dataset_pct, 
            k=10, 
            filter_viewed=False  # False - same items to every user
        ).merge(items[['item_id', 'title', 'content_type']], 
               on='item_id',
               how='left'),

        pop_sum_weight_pct.recommend(
            dataset_pct.user_id_map.external_ids[:1], 
            dataset=dataset_pct, 
            k=10, 
            filter_viewed=False  # False - same items to every user
        ).merge(items[['item_id', 'title', 'content_type']], 
               on='item_id',
               how='left'),
    ], axis=1).drop(['user_id', 'rank'], axis=1)
]
)
# |   pop_mean_weight   |   pop_sum_weight   |
# | pop_mean_weight_pct | pop_sum_weight_pct |
# Out:
#    item_id          score                                          title  \
# 0     1714  635143.666667                                Люби меня таким
# 1     3642  442423.000000                             Обручальное кольцо
# 2      856  400153.000000                              Приют комедиантов
# 3     3480  373410.666667                                    Жизнь Мехэк
# 4    16216  340005.500000                                 Анна-детективъ
# 5    13395  339193.000000                                        Крамола
# 6    11566  328638.566667                                  Татьянин день
# 7     1914  294688.000000                                  Неравный брак
# 8     2788  290355.500000                                          Ганга
# 9     3750  285721.000000                                  Юлия Высоцкая
# 0    10542     100.000000  [4К] Пресноводные черепахи Чолутека. Гондурас
# 1     1220     100.000000                                      Кит и кот
# 2     5321     100.000000                    Богатырша (жестовым языком)
# 3     9505     100.000000                             Профессор в законе
# 4     3846     100.000000                 Особо опасна (жестовым языком)
# 5     7490     100.000000                         Что там, за поворотом?
# 6     1120     100.000000                                   Крашеный лис
# 7     2170     100.000000                    [4К] Народ тавака. Гондурас
# 8     3754     100.000000                                  Ищу попутчика
# 9     2518     100.000000                                  Однажды летом
#
#   content_type  item_id         score                         title  \
# 0       series    10440  5.534083e+09                   Хрустальный
# 1       series    15297  4.432354e+09               Клиника счастья
# 2       series     4151  9.591958e+08        Секреты семейной жизни
# 3       series     6192  9.368519e+08         Отчаянные домохозяйки
# 4       series       14  8.652617e+08              Жестокий Стамбул
# 5       series    13865  8.187124e+08                      Девятаев
# 6       series     9728  7.817209e+08             Гнев человеческий
# 7       series     9996  6.297195e+08                         Немцы
# 8       series    16228  5.796793e+08                    Содержанки
# 9       series      496  4.452146e+08           Воскресший Эртугрул
# 0         film    15297  1.045158e+07               Клиника счастья
# 1         film    10440  9.449820e+06                   Хрустальный
# 2         film    13865  8.247354e+06                      Девятаев
# 3         film     9728  7.648170e+06             Гнев человеческий
# 4         film     3734  5.361004e+06  Прабабушка легкого поведения
# 5       series     4151  3.788442e+06        Секреты семейной жизни
# 6         film      142  2.786902e+06                          Маша
# 7         film     8636  2.247976e+06                    Белый снег
# 8         film     6809  2.132168e+06                         Дуров
# 9         film    11237  1.676397e+06                   День города
#
#   content_type
# 0       series
# 1       series
# 2       series
# 3       series
# 4       series
# 5         film
# 6         film
# 7       series
# 8       series
# 9       series
# 0       series
# 1       series
# 2         film
# 3         film
# 4         film
# 5       series
# 6         film
# 7         film
# 8         film
# 9         film

# %% [markdown]
# and...
# Nothing become better (may be)
# Let's compare this models in the next nootebok.
# So let's save datasets and models using pickle

# %%
import pickle
import os
os.makedirs('rectools_datasets', exist_ok=True)

with open('rectools_datasets/dataset.pickle', 'wb') as handle:
    pickle.dump(dataset, handle)
with open('rectools_datasets/dataset_pct.pickle', 'wb') as handle:
    pickle.dump(dataset_pct, handle)

# %%
os.makedirs('pop_models', exist_ok=True)

with open('pop_models/pop_sum_weight.pickle', 'wb') as handle:
    pickle.dump(pop_sum_weight, handle)
    
with open('pop_models/pop_sum_weight_pct.pickle', 'wb') as handle:
    pickle.dump(pop_sum_weight_pct, handle)
    
with open('pop_models/pop_n_users.pickle', 'wb') as handle:
    pickle.dump(pop_n_users, handle)
    
with open('pop_models/pop_n_interactions.pickle', 'wb') as handle:
    pickle.dump(pop_n_interactions, handle)

# %% [markdown]
# Checking that everything has been saved correct

# %%
with open('rectools_datasets/dataset.pickle', 'rb') as handle:
    dataset = pickle.load(handle)
    
with open('rectools_datasets/dataset_pct.pickle', 'rb') as handle:
    dataset_pct = pickle.load(handle)

with open('pop_models/pop_sum_weight.pickle', 'rb') as handle:
    pop_sum_weight = pickle.load(handle)
    
with open('pop_models/pop_sum_weight_pct.pickle', 'rb') as handle:
    pop_sum_weight_pct = pickle.load(handle)
    
with open('pop_models/pop_n_users.pickle', 'rb') as handle:
    pop_n_users = pickle.load(handle)
    
with open('pop_models/pop_n_interactions.pickle', 'rb') as handle:
    pop_n_interactions = pickle.load(handle)

# %%
pd.concat([
    pop_n_users.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
    
    pop_n_interactions.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
    
    pop_sum_weight.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
    
    pop_sum_weight_pct.recommend(
        dataset_pct.user_id_map.external_ids[:1], 
        dataset=dataset_pct, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    ).merge(items[['item_id', 'title', 'content_type']], 
           on='item_id',
           how='left'),
], axis=1).drop(['user_id', 'rank'], axis=1)
# Out:
#    item_id     score                         title content_type  item_id  \
# 0    10440  202457.0                   Хрустальный       series    10440
# 1    15297  193123.0               Клиника счастья       series    15297
# 2     9728  132865.0             Гнев человеческий         film     9728
# 3    13865  122119.0                      Девятаев         film    13865
# 4     4151   91167.0        Секреты семейной жизни       series     4151
# 5     3734   74803.0  Прабабушка легкого поведения         film     3734
# 6     2657   68581.0                    Подслушано       series     2657
# 7     4880   55043.0                         Афера       series     4880
# 8      142   45367.0                          Маша         film      142
# 9     6809   40372.0                         Дуров         film     6809
#
#       score                         title content_type  item_id         score  \
# 0  202457.0                   Хрустальный       series    10440  5.534083e+09
# 1  193123.0               Клиника счастья       series    15297  4.432354e+09
# 2  132865.0             Гнев человеческий         film     4151  9.591958e+08
# 3  122119.0                      Девятаев         film     6192  9.368519e+08
# 4   91167.0        Секреты семейной жизни       series       14  8.652617e+08
# 5   74803.0  Прабабушка легкого поведения         film    13865  8.187124e+08
# 6   68581.0                    Подслушано       series     9728  7.817209e+08
# 7   55043.0                         Афера       series     9996  6.297195e+08
# 8   45367.0                          Маша         film    16228  5.796793e+08
# 9   40372.0                         Дуров         film      496  4.452146e+08
#
#                     title content_type  item_id       score  \
# 0             Хрустальный       series    15297  10451575.0
# 1         Клиника счастья       series    10440   9449820.0
# 2  Секреты семейной жизни       series    13865   8247354.0
# 3   Отчаянные домохозяйки       series     9728   7648170.0
# 4        Жестокий Стамбул       series     3734   5361004.0
# 5                Девятаев         film     4151   3788442.0
# 6       Гнев человеческий         film      142   2786902.0
# 7                   Немцы       series     8636   2247976.0
# 8              Содержанки       series     6809   2132168.0
# 9     Воскресший Эртугрул       series    11237   1676397.0
#
#                           title content_type
# 0               Клиника счастья       series
# 1                   Хрустальный       series
# 2                      Девятаев         film
# 3             Гнев человеческий         film
# 4  Прабабушка легкого поведения         film
# 5        Секреты семейной жизни       series
# 6                          Маша         film
# 7                    Белый снег         film
# 8                         Дуров         film
# 9                   День города         film

# %% [markdown]
# Let's save offline result of POPRecs

# %%
recos = pop_sum_weight.recommend(
    dataset.user_id_map.external_ids, 
    dataset=dataset, 
    k=20, 
    filter_viewed=True
)

# %%
os.makedirs('pop_models_offline', exist_ok=True)
recos.to_csv('pop_models_offline/pop_sum_weight.csv')

# %%
users_items_dict = recos.groupby('user_id')['item_id'].apply(list).to_dict()
users_items_dict[176549]
# Out:
# [10440,
#  15297,
#  4151,
#  6192,
#  14,
#  13865,
#  9996,
#  16228,
#  496,
#  3734,
#  6006,
#  7476,
#  2657,
#  5471,
#  4880,
#  12192,
#  2720,
#  6809,
#  11640,
#  8270]

# %%
import json
with open('pop_models_offline/pop_sum_weight_offline.json', 'w') as handle:
    json.dump(users_items_dict, handle)

# %%
pop_sum_weight.recommend(
        dataset.user_id_map.external_ids[:1], 
        dataset=dataset, 
        k=10, 
        filter_viewed=False  # False - same items to every user
    )['item_id'].tolist()
# Out:
# [10440, 15297, 4151, 6192, 14, 13865, 9728, 9996, 16228, 496]
